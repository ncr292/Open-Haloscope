# %% [markdown]
# Circuit simulation of the Open Haloscope hardware

# %%
import numpy as np
import matplotlib.pyplot as plt

# lcapy
from lcapy import Circuit, j, omega, s

# %%
cct1 = Circuit( """
                Vi 1 0_1 step; down
                R 1 2; right=1.5
                Cx 2 3; down=1
                L 3 4; down=1
                C 4 0; down=1
                W 0_3 0; left=1
                W 0_1 0; right
                P1 2_2 0_2; down
                W 2 2_2; right=1
                """ )

# %%
cct1.draw(cpt_size=1, node_spacing=1.5, scale=0.75)

# %%
cct2 = Circuit( """
                Vi 1 0_1 step; down
                R 1 2; right=1.5
                Cx 2 3; down=1
                C 3 0; down=1
                W 3 3_1; right=0.5
                L 3_1 0_3; down=1
                W 0_3 0; left=0.5
                W 0_1 0; right
                W 0 0_2; right=1
                P1 2_2 0_2; down
                W 2 2_2;right=1
                """ )

# %%
cct2.draw(cpt_size=1, node_spacing=1.5, scale=0.75)

# %%
H = (cct1.C.V(s) / cct1.Vi.V(s)).simplify()

# %%
C = 1e-8
R = 1e1
L = 1e-4
Cx = 1e-9


H1 = H.subs('C',C).subs('R',R).subs('Cx',Cx).subs('L',L)
H1(j * omega)
H
# Out:
#                       2
#                 Cₓ⋅L⋅s
# ────────────────────────────────────────
#           3               2
# C⋅Cₓ⋅L⋅R⋅s  + Cₓ⋅R⋅s + L⋅s ⋅(C + Cₓ) + 1

# %%
w = np.logspace(4, 8, 500)

ax = H1(j * omega).dB.plot(w, log_frequency=True)
ax = H1(j * omega).phase_degrees.plot(w, log_frequency=True)
